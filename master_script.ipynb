# %%
#DATA ENGINEERING
#IMPORT LIBS
from pandas.io.json import json_normalize
import json
import pandas as pd
import numpy as np
import datetime
from datetime import date
import calendar

# %%
#COPIES THE CONTENT OF A JSON FILE INTO A DATAFRAME
data = pd.read_json('News_Category_Dataset.json', lines=True)

# %%
idx=list(np.arange(1,200854))
date_list=list(data['date'])
author_list=list(data['authors'])
category_list=list(data['category'])
headline_list=list(data['headline'])
link_list=list(data['link'])
short_list=list(data['short_description'])

# %%
#EXTRACT EXTRA FEATURES LIKE DAY OF THE WEEK FROM EXISTING DATA AND APPEND ALL THE DATA TO A CSV
day=[]
weekday=[]
month_list=[]
year_list=[]

for i in date_list:
    d_name=calendar.day_name[i.weekday()]
    weekday.append(d_name)
    datee = datetime.datetime.strptime(str(i), "%Y-%m-%d %H:%M:%S")

    m=datee.month
    month_list.append(m)
    y=datee.year
    year_list.append(y)
    d=datee.day
    day.append(d)

clean_data=pd.DataFrame({'SERIAL_NUMBER':idx,'DATE':date_list,'YEAR':year_list,'MONTH':month_list,'DAY':day,'DAY_OF_WEEK':weekday,'AUTHOR':author_list,'CATEGORY':category_list,'HEADLINE':headline_list,'LINK':link_list,'SHORT_DESC':short_list})

# %%
clean_data.to_csv('master_data.csv',sep=',',header=True,index=False)

# %%
#DATA ANALYSIS
#IMPORT LIBS
import re
import pandas as pd # CSV file I/O (pd.read_csv)
from nltk.corpus import stopwords
import numpy as np
import sklearn
import nltk
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score ,confusion_matrix
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %%
master_data = pd.read_csv("master_data.csv")
master_data['AUTHOR'] = master_data['AUTHOR'].fillna('None')
#print(news)
#[	SERIAL_NUMBER	DATE	YEAR	MONTH	DAY	DAY_OF_WEEK	AUTHOR	CATEGORY	HEADLINE	LINK	SHORT_DESC]

# %%
#FUNCTION TO CROP DATA BETWEEN TWO GIVEN DATES
def data_slicer(start_date,end_date):
    index = pd.date_range(start=start_date,end=end_date)
    date_list=[]
    for ch in index:
        datee = datetime.datetime.strptime(str(ch), "%Y-%m-%d %H:%M:%S")
        datee2=datee.strftime("%d-%m-%Y")
        date_list.append(datee2)
    data_req=master_data[master_data['DATE'].isin(date_list)]
    return data_req

print(data_slicer('26-06-2012','31-12-2012'))
# Out:
#         Unnamed: 0  SERIAL_NUMBER        DATE  YEAR  MONTH  DAY DAY_OF_WEEK  \
# 169498      169498         169499  31-12-2012  2012     12   31      Monday
# 169499      169499         169500  31-12-2012  2012     12   31      Monday
# 169500      169500         169501  31-12-2012  2012     12   31      Monday
# 169501      169501         169502  31-12-2012  2012     12   31      Monday
# 169502      169502         169503  31-12-2012  2012     12   31      Monday
# 169503      169503         169504  31-12-2012  2012     12   31      Monday
# 169504      169504         169505  31-12-2012  2012     12   31      Monday
# 169505      169505         169506  31-12-2012  2012     12   31      Monday
# 169506      169506         169507  31-12-2012  2012     12   31      Monday
# 169507      169507         169508  31-12-2012  2012     12   31      Monday
# 169508      169508         169509  31-12-2012  2012     12   31      Monday
# 169509      169509         169510  31-12-2012  2012     12   31      Monday
# 22563   To combat sexual harassment in public spaces, ...
# 22564   Despite its official policy of non-interventio...
# 22565   LGBTQ rights get a big win in Europe's most po...
# 22566   CREW says the Hatch Act prohibits the ambassad...
# 22567   Not even Kris Kobach, head of a presidential v...
# 22568   Not all pharmacists are clear on who should ge...
# 22569                       According to science, anyway.
# 22570                          And Brzezinski's response.
# 22571   Officials insist the goal is to better protect...
# 22572   Gavin Long set out to inflict "destruction ......
# 22573   The recent uncovering of a major baby-traffick...
# 22574   ”Maybe she’s born with it ... Maybe she’s a ti...
# 22575   But she clarified that her win hadn't "meant n...
# 22576   It's a presidential tweet, so take it seriousl...
# 22577                           "I was a teenage parent."
# 22578                          These photos are so sweet!
# 22579   State officials are refusing to disclose data ...
# 22580   The host was discussing Jared Kushner -- obvio...
# 22581     Much of the acclaimed show's cast is returning.
# 22582   The Trump administration has already rolled ba...
# 22583   Scientists, former agency officials and House ...
# 22584   “When our democracy is sick, we must be the he...
# ...                                                   ...
# 189251  And participants in the study made healthier c...
# 189252  Growing up, we idolized Snow White...and her l...
# 189253  When it comes to the point where marriage -- a...
# 189254  The life experience of being a mother has alwa...
# 189255            Each layer more glorious than the last.
# 189256  We love a bone-chillingly cold Martini as much...
# 189257  The Best Divorce Advice On YourTango You have ...
# 189258  As always, this taste test is not sponsored or...
# 189259  Adult ADHD doesn't have to be a bad thing. Whe...
# 189260  2) Learn to delegate. "I felt like I had to be...
# 189261  Have a pound cake lying around your kitchen? T...
# 189262  Want more? Be sure to check out Stylelist on T...
# 189263  Gruenberg said the FDIC would investigate bank...
# 189264  "This is an act of daily living for people now...
# 189265  As far as he knows, he's the world's first pol...
# 189266  For an equally powerful video, watch Texas mot...
# 189267  If the government sent you a half-million doll...
# 189268  MY husband and I starting talking divorce at m...
# 189269  Isn't it amazing how persuasive kids can be an...
# 189270  Photos: Wall Drug, TravelSD.com; Tinkertown Mu...
# 189271  June 1 has the dubious distinction of being th...
# 189272  The actual festivities, which mark the monach'...
# 189273  This week's Family Dinner Table Talk, from Huf...
# 189274  On May 31, Arianna Huffington appeared on Life...
# 189275  For every celebrity who talks publicly about t...
# 189276  A long-divorced friend of mine is struggling w...
# 189277  Here is a collection of fun gifts for dad that...
# 189278  The study, to be published in the Archives of ...
# 189279  We've all heard that nearly half of all marria...
# 189280  Rarely do kids want a mom with biceps like can...
#
# [16183 rows x 12 columns]

# %%
#FUNCTION TO GET A PARTICULAR DAY OF THE WEEK DATA FROM ALL 6 YEARS
def day_of_week(day_name):
    data_req=master_data[master_data['DAY_OF_WEEK'] == day_name]
    return data_req

print(day_of_week('Monday'))
# Out:
#         Unnamed: 0  SERIAL_NUMBER        DATE  YEAR  MONTH  DAY DAY_OF_WEEK  \
# 276            276            277  21-05-2018  2018      5   21      Monday
# 277            277            278  21-05-2018  2018      5   21      Monday
# 278            278            279  21-05-2018  2018      5   21      Monday
# 279            279            280  21-05-2018  2018      5   21      Monday
# 280            280            281  21-05-2018  2018      5   21      Monday
# 200705  https://www.huffingtonpost.com/entry/five-unex...
# 200706  https://www.huffingtonpost.com/entry/dsm-5-aut...
# 200707  https://www.huffingtonpost.com/entry/bella-san...
# 200708  https://www.huffingtonpost.comhttp://www.nytim...
# 200709  https://www.huffingtonpost.com/entry/tsa-worke...
# 200710  https://www.huffingtonpost.com/entry/kylie-ken...
# 200711  https://www.huffingtonpost.comhttp://online.ws...
# 200712  https://www.huffingtonpost.com/entry/kendall-k...
# 200713  https://www.huffingtonpost.com/entry/kelly-wea...
# 200714  https://www.huffingtonpost.comhttp://www.nytim...
# 200715  https://www.huffingtonpost.com/entry/water-par...
# 200716  https://www.huffingtonpost.com/entry/the-hotte...
# 200717  https://www.huffingtonpost.com/entry/grieving-...
# 200718  https://www.huffingtonpost.com/entry/jump-rope...
# 200719  https://www.huffingtonpost.com/entry/minding-y...
# 200720  https://www.huffingtonpost.com/entry/berenice-...
# 200721  https://www.huffingtonpost.com/entry/archaeoto...
#
#                                                SHORT_DESC
# 276     The State Department has already announced tha...
# 277     “We have to preserve this agreement so we don’...
# 278     "It was organized fascists who attacked me as ...
# 279     This was not the first moment addressing gun v...
# 280     The Tamir Rice Afrocentric Cultural Center wil...
# 281     Plaintiffs complained that the state violated ...
# 282               "Why don't we change what's happening?"
# 283     The Pulitzer Prize-winning artist gave her ano...
# 284     His words, reportedly uttered in private, have...
# 285     The supposed "interstellar immigrant" is locat...
# 286     “People didn’t view me seriously because I was...
# 287     Any action is an "effort to silence me," the c...
# 288     The New York governor faces former "Sex and th...
# 289     A new ruling allows employers to force workers...
# 290     A Texas newspaper filed a lawsuit alleging the...
# 291     The author hopes "The Music of What Happens" w...
# 292     A new documentary examines the "culture of exc...
# 293                   This is postpartum life unfiltered.
# 294     "It felt like the world was becoming a better ...
# 295     You have a few options this week, including a ...
# 296     Netflix announced a deal with Barack and Miche...
# 297                                       Ther-oh-my-God!
# 298     "If you can't beat 'em, join 'em," Clinton sai...
# 299     “We can’t let our guy go in and be questioned ...
# 300     It's a revival of a successful tactic Dems use...
# 301     The star veered from the traditional script, r...
# 302     Our poll showed some surprising generational d...
# 303     Most of those following the Trump-Russia inves...
# 304     The proposal would allow hunters to kill bear ...
# 305     Trump told Stern: "You know who’s a great beau...
# ...                                                   ...
# 200692  I guess it really is a Brad, Brad World... oh ...
# 200693  The 18th annual Screen Actors Guild Awards wen...
# 200694  When our partner Yoga Journal put out the call...
# 200695  Fame WHAT: The chic actress stepped out with b...
# 200696  While the Golden Globes glow has faded and the...
# 200697  There are ways to push through the invisible w...
# 200698  If you're shopping around for a mattress now o...
# 200699  We've warned you before: if you play it safe o...
# 200700  There's certain joie de vivre to New Orleans t...
# 200701  What's your favorite water park in California?...
# 200702  The most challenging aspect of being a writer?...
# 200703  Not all stars opt for lavish, over-the-top wed...
# 200704  Read through and then tell us: what would be o...
# 200705  In order to fully recover in a healthy way fro...
# 200706  Marja-Leena Mattila of the University of Oulu ...
# 200707  ABC News reported that Bella has pneumonia in ...
# 106     Dylan Farrow called her brother's essay "beyon...
# 135                               The score is love-love.
# 148     The TV singing competition's new champion just...
# 175     The "Ocean's 8" star delivered in imitating Dr...
# 182     “The president spelled ‘Illinois’ wrong in his...
# 186     Teams can set their own policies for punishing...
# 213     So that means she and Orlando Bloom are defini...
# 218                       Skills and showmanship, people.
# 219     The "Solo" star's Wookiee mistake is pretty hi...
# 220     "I win either way," second-place finisher Cale...
# 227     "How can you not be pansexual in space?" he said.
# 312     She delivered an iconic performance and speech...
# 316                         Monarchy, love and fast food.
# 317          Watch him try to rehabilitate the rehab biz.
# 386            "#BaldwinitosEverywhere," the actor wrote.
# 393     Welcome to the next chapter in the decline of ...
# 404          The actress makes an intriguing observation.
# 409     "I got a lot of sh** for it," the Aerosmith ro...
# 442               And it's narrated by the comedian, too.
# ...                                                   ...
# 182921  Ensuring that residents in nursing homes and o...
# 183569  The next time we're approached by someone aski...
# 184055  Life is just a series of processes.  Every pro...
# 184090  Adam Cheshire, now 16 months old, has taken hi...
# 184267  Nature if not yet medicine is trying to warn u...
# 184455  Once kids enter the equation, the whole dynami...
# 185277  As the calendar took me into my 40's, I fell i...
# 186996  A girl serves as the vehicle for the ad's litt...
# 187860  The two are often asked to comment on what's r...
# 189089  Commercial music takes up about 25 percent of ...
# 189791  What are we going to do about all of the "non-...
# 190150  It's time for the U.S. to catch up with the re...
# 191024  Now Gap has released a campaign featuring two ...
# 191105  If you are a mother, grandmother or aunt with ...
# 191967  Owning a thoroughbred outright often requires ...
# 192534  With practice, mindstrength is an effective to...
# 192797  But parents can combat the urge to keep up wit...
# 194795  You probably have told yourself a hundred time...
# 195979  Sadly, in the ongoing, often vitriolic debates...
# 196481  Music therapy services in medical settings suc...
# 196989  Here comes the pitch, bargain-hungry baseball ...
# 198268  Sunday's Academy Awards are all about celebrat...
# 198269  Of course, Oscar spots won't reach nearly as m...
# 198880  Telling a few loved ones that I'm gay has been...
# 198892  Now that Lin is defending his name, perhaps ev...
# 198986  In order to provide clients with a "simple use...
# 199483  Branding wonks have thrown out many comparison...
# 200206  New England Patriots quarterback Tom Brady and...
# 200246  Even though every cloud might have a silver li...
# 200803  When designing a home, I generally believe the...
#
# [2067 rows x 12 columns]

# %%
#DATE TO DATE REPORTS
def date_to_date_analysis(start_date,end_date):
    data=data_slicer(start_date,end_date)
    category_count={}
    author_article_count={}
    year_list=list(set(list(data['YEAR'])))
    category_list=list(set(list(data['CATEGORY'])))
    authors_list=list(set(list(data['AUTHOR'])))
    print("\nThe active year/s in the given range :",year_list)
    print("\nThe categories published :",category_list)
    print("\nThe number of active authors :",len(authors_list))
    for cat in category_list:
        data1=data[data['CATEGORY']==cat]
        category_count[cat] = data1['CATEGORY'].count()
    print(category_count)
    
    for cat in authors_list:
        data1=data[data['AUTHOR']==cat]
        author_article_count[cat] = data1['AUTHOR'].count()
    #print(author_article_count)
    
    high_auth=[]
    highest_count=0
    highest_name='AA'
    for name,count in author_article_count.items():
        if count>highest_count:
            highest_count=count
            highest_name=name
        if count > 200:
            high_auth.append(name)
    print("\nAuthors who wrote more than 200 posts:",high_auth)
    print("\nMost Active Author in the given date range :",highest_name,highest_count)

date_to_date_analysis('26-05-2016','29-06-2017')
# Out:
# The active year/s in the given range : [2016, 2017]
#
# The categories published : ['ARTS & CULTURE', 'TECH', 'IMPACT', 'EDUCATION', 'THE WORLDPOST', 'GREEN', 'GOOD NEWS', 'WEIRD NEWS', 'STYLE', 'WORLDPOST', 'ARTS', 'PARENTS', 'HEALTHY LIVING', 'BLACK VOICES', 'CRIME', 'SPORTS', 'BUSINESS', 'ENTERTAINMENT', 'WORLD NEWS', 'COLLEGE', 'TASTE', 'SCIENCE', 'LATINO VOICES', 'MEDIA', 'FIFTY', 'RELIGION', 'COMEDY', 'QUEER VOICES', 'WOMEN', 'TRAVEL', 'POLITICS']
#
# The number of active authors : 6110
# {'ARTS & CULTURE': 836, 'TECH': 277, 'IMPACT': 402, 'EDUCATION': 173, 'THE WORLDPOST': 2575, 'GREEN': 550, 'GOOD NEWS': 328, 'WEIRD NEWS': 739, 'STYLE': 474, 'WORLDPOST': 151, 'ARTS': 52, 'PARENTS': 1167, 'HEALTHY LIVING': 1458, 'BLACK VOICES': 1187, 'CRIME': 722, 'SPORTS': 970, 'BUSINESS': 702, 'ENTERTAINMENT': 3685, 'WORLD NEWS': 404, 'COLLEGE': 117, 'TASTE': 546, 'SCIENCE': 200, 'LATINO VOICES': 372, 'MEDIA': 599, 'FIFTY': 99, 'RELIGION': 483, 'COMEDY': 1332, 'QUEER VOICES': 1478, 'WOMEN': 956, 'TRAVEL': 403, 'POLITICS': 11713}
#
# Authors who wrote more than 200 posts: ['Andy McDonald', 'Matthew Jacobs', 'Rebecca Shapiro', 'Sara Boboltz', 'Caroline Bologna', 'Hilary Hanson', 'Taylor Pittman', 'Carly Ledbetter', 'Jamie Feldman', 'Mary Papenfuss', 'Jenna Amatulli', 'Ron Dicker', 'Marina Fang', 'Sam Levine', 'Ed Mazza', 'Cristian Farias', 'Paige Lavender', 'Bill Bradley', 'Lee Moran', 'Igor Bobic', 'James Michael Nichols', 'Lauren Weber', 'Daniel Marans', 'Julia Brucculieri', 'David Moye', 'Nina Golgowski', 'Steven Hoffer', 'Carla Herreria', 'None', 'Cole Delbyck', 'Curtis M. Wong']
#
# Most Active Author in the given date range : None 2870

# %%
master_data.groupby(by='CATEGORY').size()
# Out:
# CATEGORY
# ARTS               1509
# ARTS & CULTURE     1339
# BLACK VOICES       4528
# BUSINESS           5937
# COLLEGE            1144
# COMEDY             5175
# CRIME              3405
# CULTURE & ARTS     1030
# DIVORCE            3426
# EDUCATION          1004
# ENTERTAINMENT     16058
# ENVIRONMENT        1323
# FIFTY              1401
# FOOD & DRINK       6226
# GOOD NEWS          1398
# GREEN              2622
# HEALTHY LIVING     6694
# HOME & LIVING      4195
# IMPACT             3459
# LATINO VOICES      1129
# MEDIA              2815
# MONEY              1707
# PARENTING          8677
# PARENTS            3955
# POLITICS          32739
# QUEER VOICES       6314
# RELIGION           2556
# SCIENCE            2178
# SPORTS             4884
# STYLE              2254
# STYLE & BEAUTY     9649
# TASTE              2096
# TECH               2082
# THE WORLDPOST      3664
# TRAVEL             9887
# WEDDINGS           3651
# WEIRD NEWS         2670
# WELLNESS          17827
# WOMEN              3490
# WORLD NEWS         2177
# WORLDPOST          2579
# dtype: int64

# %%
#count the number of author in the dataset
#news.authors.value_counts()
total_authors = master_data.AUTHOR.nunique()
news_counts = master_data.shape[0]
print('Total Number of authors : ', total_authors)
print('avg articles written by per author: ' + str(news_counts//total_authors))
print('Total news counts : ' + str(news_counts))
# Out:
# Total Number of authors :  27993
# avg articles written by per author: 7
# Total news counts : 200853

# %%
#DERIVING INFERENCES
authors_news_counts = master_data.AUTHOR.value_counts()
sum_contribution = 0
author_count = 0
for author_contribution in authors_news_counts:
    author_count += 1
    if author_contribution < 80:
        break
    sum_contribution += author_contribution
print('{} of news is contributed by {} authors i.e  {} % of news is contributed by {} % of authors'.
      format(sum_contribution, author_count, format((sum_contribution*100/news_counts), '.2f'), format((author_count*100/total_authors), '.2f')))
# Out:
# 116604 of news is contributed by 259 authors i.e  58.05 % of news is contributed by 0.93 % of authors

# %%
master_data.AUTHOR.value_counts()[0:10]
# Out:
# None                 36620
# Lee Moran             2423
# Ron Dicker            1913
# Reuters, Reuters      1562
# Ed Mazza              1322
# Cole Delbyck          1140
# Andy McDonald         1068
# Julia Brucculieri     1059
# Carly Ledbetter       1054
# Curtis M. Wong        1020
# Name: AUTHOR, dtype: int64

# %%
author_name = 'Lee Moran'
#author_name = 'Ed Mazza'
particular_author_news = master_data[master_data['AUTHOR'] == author_name]
df = particular_author_news.groupby(by='CATEGORY')['HEADLINE'].count()
df
# Out:
# CATEGORY
# ARTS & CULTURE     41
# BLACK VOICES       29
# BUSINESS            2
# COMEDY            779
# CRIME              92
# EDUCATION           1
# ENTERTAINMENT     387
# GOOD NEWS          74
# GREEN               2
# IMPACT             12
# LATINO VOICES       6
# MEDIA              46
# PARENTS            41
# POLITICS          263
# QUEER VOICES        6
# RELIGION            7
# SCIENCE            46
# SPORTS            101
# STYLE               3
# TASTE              12
# TECH               18
# THE WORLDPOST      25
# TRAVEL              4
# WEIRD NEWS        390
# WOMEN              25
# WORLD NEWS         11
# Name: HEADLINE, dtype: int64

# %%
#DATA VISUALIZATION
fig, ax = plt.subplots(1, 1, figsize=(35,7))
sns.countplot(x = 'CATEGORY', data = master_data)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15,15))
master_data['CATEGORY'].value_counts().plot.pie( autopct = '%1.1f%%')

# %%
data_2012=data_slicer('26-06-2012','31-12-2012')
data_2013=data_slicer('01-01-2013','31-12-2013')
data_2014=data_slicer('01-06-2014','31-12-2014')
data_2015=data_slicer('01-06-2015','31-12-2015')
data_2016=data_slicer('01-06-2016','31-12-2016')
data_2017=data_slicer('01-06-2017','31-12-2017')
data_2018=data_slicer('01-06-2018','26-05-2018')

# %%
#2012
fig, ax = plt.subplots(1, 1, figsize=(10,10))
data_2012['CATEGORY'].value_counts().plot.pie( autopct = '%1.1f%%')
#MOST ACTIVE AUTHOR
x12=data_2012['AUTHOR'].value_counts()
print("Top 5 authors in 2012 \n",x12[:6])
# Out:
# Top 5 authors in 2012
#  None                5048
# Reuters, Reuters     414
# Michelle Manetti     269
# Rebecca Adams        203
# Michelle Persad      197
# Amy Marturana        182
# Name: AUTHOR, dtype: int64

# %%
#2013
fig, ax = plt.subplots(1, 1, figsize=(10,10))
data_2013['CATEGORY'].value_counts().plot.pie( autopct = '%1.1f%%')
x13=data_2013['AUTHOR'].value_counts()
print("\nTop 5 authors in 2013 \n",x13[:6])
# Out:
# Top 5 authors in 2013
#  None                11246
# Reuters, Reuters      681
# Michelle Manetti      555
# Rebecca Adams         342
# Dana Oliver           317
# Michelle Persad       295
# Name: AUTHOR, dtype: int64

# %%
#2014
fig, ax = plt.subplots(1, 1, figsize=(8,8))
data_2014['CATEGORY'].value_counts().plot.pie( autopct = '%1.1f%%')
x14=data_2014['AUTHOR'].value_counts()
print("\nTop 5 authors in 2014 \n",x14[:6])
# Out:
# Top 5 authors in 2014
#  None                    4970
# Dana Oliver              201
# Chris Greenberg          181
# Jamie Feldman            173
# JamesMichael Nichols     173
# Priscilla Frank          171
# Name: AUTHOR, dtype: int64

# %%
#2015
fig, ax = plt.subplots(1, 1, figsize=(8,8))
data_2015['CATEGORY'].value_counts().plot.pie( autopct = '%1.1f%%')
x15=data_2015['AUTHOR'].value_counts()
print("\nTop 5 authors in 2015 \n",x15[:6])
# Out:
# Top 5 authors in 2015
#  None                 4968
# Bill Bradley          336
# Lily Karlin           321
# Julia Brucculieri     318
# Ron Dicker            274
# E. Oliver Whitney     256
# Name: AUTHOR, dtype: int64

# %%
#2016
fig, ax = plt.subplots(1, 1, figsize=(8,8))
data_2016['CATEGORY'].value_counts().plot.pie( autopct = '%1.1f%%')
x16=data_2016['AUTHOR'].value_counts()
print("\nTop 5 authors in 2016 \n",x16[:6])
# Out:
# Top 5 authors in 2016
#  None                 4946
# Lee Moran             811
# Cole Delbyck          546
# Julia Brucculieri     536
# Ron Dicker            535
# Carly Ledbetter       440
# Name: AUTHOR, dtype: int64

# %%
#2017
fig, ax = plt.subplots(1, 1, figsize=(8,8))
data_2017['CATEGORY'].value_counts().plot.pie( autopct = '%1.1f%%')
x17=data_2017['AUTHOR'].value_counts()
print("\nTop 5 authors in 2017 \n",x17[:6])
# Out:
# Top 5 authors in 2017
#  None                1172
# Lee Moran            867
# Mary Papenfuss       603
# Ron Dicker           495
# Ed Mazza             381
# Caroline Bologna     337
# Name: AUTHOR, dtype: int64

# %%
#2018
fig, ax = plt.subplots(1, 1, figsize=(8,8))
data_2018['CATEGORY'].value_counts().plot.pie( autopct = '%1.1f%%')

x18=data_2018['AUTHOR'].value_counts()
print("\nTop 5 authors in 2018 \n",x18[:6])
# Out:
# Top 5 authors in 2018
#  Lee Moran         610
# Ed Mazza          402
# Ron Dicker        375
# Mary Papenfuss    301
# Jenna Amatulli    266
# Curtis M. Wong    243
# Name: AUTHOR, dtype: int64

# %%
#MONTH WISE ANALYSIS
mon=month_data(1)
mon_split=mon['CATEGORY'].value_counts()
mon_split=list(mon_split.index)
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') & (mon['CATEGORY'] == 'WELLNESS') & (mon['CATEGORY'] == 'ENTERTAINMENT') & (mon['CATEGORY'] == 'PARENTING') & (mon['CATEGORY']=='TRAVEL')]
mon_split_1=mon[(mon['CATEGORY'] == 'BUSINESS') & (mon['CATEGORY'] == 'SPORTS') & (mon['CATEGORY'] == 'MEDIA') & (mon['CATEGORY'] == 'ENVIRONMENT') & (mon['CATEGORY']=='EDUCATION')]

# %%
#Jan
mon=month_data(1)
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in JAN \n",x18[:6])
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])
# Out:
# Top 5 authors in JAN
#  None              3081
# Lee Moran          265
# Ron Dicker         203
# Cole Delbyck       141
# Mary Papenfuss     132
# Ellie Krupnick     128
# Name: AUTHOR, dtype: int64

# %%
#FEB
mon=month_data(2)
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in FEB \n",x18[:6])
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])
# Out:
# Top 5 authors in FEB
#  None                3098
# Lee Moran            293
# Ron Dicker           177
# Reuters, Reuters     156
# Dana Oliver          150
# Ellie Krupnick       142
# Name: AUTHOR, dtype: int64

# %%
#MAR
mon=month_data(3)
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in MAR \n",x18[:6])
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])
# Out:
# Top 5 authors in MAR
#  None                3428
# Lee Moran            265
# Ron Dicker           204
# Reuters, Reuters     192
# Ellie Krupnick       175
# Ed Mazza             148
# Name: AUTHOR, dtype: int64

# %%
#APR
mon=month_data(4)
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in APR \n",x18[:6])
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])
# Out:
# Top 5 authors in APR
#  None                3083
# Lee Moran            223
# Ron Dicker           186
# Ed Mazza             162
# Reuters, Reuters     156
# Mary Papenfuss       143
# Name: AUTHOR, dtype: int64

# %%
#MAY
mon=month_data(5)
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in MAY \n",x18[:6])
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])
# Out:
# Top 5 authors in MAY
#  None                3295
# Lee Moran            241
# Ron Dicker           193
# Ed Mazza             152
# Mary Papenfuss       138
# Reuters, Reuters     118
# Name: AUTHOR, dtype: int64

# %%
#JUN
mon=month_data(6)
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in JUN \n",x18[:6])
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])
# Out:
# Top 5 authors in JUN
#  None                3125
# Reuters, Reuters     128
# Ron Dicker            90
# Lee Moran             83
# Rebecca Adams         77
# Curtis M. Wong        71
# Name: AUTHOR, dtype: int64

# %%
#JULY
mon=month_data(7)
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in JULY \n",x18[:6])
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])

# %%
#AUG
mon=month_data(8)
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in AUG \n",x18[:6])
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])
# Out:
# Top 5 authors in AUG
#  None                 3305
# Ron Dicker            162
# Julia Brucculieri     118
# Lee Moran             109
# Michelle Manetti      108
# Ed Mazza              108
# Name: AUTHOR, dtype: int64

# %%
#SEP
mon=month_data(9)
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in SEP \n",x18[:6])
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])
# Out:
# Top 5 authors in SEP
#  None                 2906
# Ron Dicker            162
# Reuters, Reuters      125
# Lee Moran             115
# Bill Bradley          105
# Julia Brucculieri     101
# Name: AUTHOR, dtype: int64

# %%
#OCT
mon=month_data(10)
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in OCT \n",x18[:6])
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])
# Out:
# Top 5 authors in OCT
#  None                 2914
# Lee Moran             174
# Ron Dicker            164
# Reuters, Reuters      112
# Julia Brucculieri     106
# Bill Bradley          103
# Name: AUTHOR, dtype: int64

# %%
#NOV
mon=month_data(11)
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in NOV \n",x18[:6])
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])
# Out:
# Top 5 authors in NOV
#  None                 2728
# Lee Moran             257
# Ron Dicker            150
# Cole Delbyck          133
# Reuters, Reuters      115
# Julia Brucculieri     101
# Name: AUTHOR, dtype: int64

# %%
#DEC
mon=month_data(12)
x18=mon['AUTHOR'].value_counts()
print("\nTop 5 authors in DEC \n",x18[:6])
mon_split_1=mon[(mon['CATEGORY'] == 'POLITICS') | (mon['CATEGORY'] == 'WELLNESS') | (mon['CATEGORY'] == 'ENTERTAINMENT') | (mon['CATEGORY'] == 'PARENTING') | (mon['CATEGORY']=='TRAVEL')]
mon_split_2=mon[(mon['CATEGORY'] == 'BUSINESS') | (mon['CATEGORY'] == 'SPORTS') | (mon['CATEGORY'] == 'MEDIA') | (mon['CATEGORY'] == 'ENVIRONMENT') | (mon['CATEGORY']=='EDUCATION')]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
sns.despine(left=True)
sns.countplot(x = 'CATEGORY', data = mon_split_1,ax=axes[0])
sns.countplot(x = 'CATEGORY', data = mon_split_2,ax=axes[1])
# Out:
# Top 5 authors in DEC
#  None               2643
# Lee Moran           254
# Ron Dicker          137
# Mary Papenfuss      130
# Ellie Krupnick      119
# Carly Ledbetter     116
# Name: AUTHOR, dtype: int64

# %%
mon_data=day_of_week('Monday')
tue_data=day_of_week('Tuesday')
wed_data=day_of_week('Wednesday')
thu_data=day_of_week('Thurday')
fri_data=day_of_week('Friday')
sat_data=day_of_week('Saturday')
sun_data=day_of_week('Sunday')

weekday_data = pd.concat([mon_data,tue_data,wed_data,thu_data])
weekend_data = pd.concat([fri_data,sat_data,sun_data])

# %%
x18=weekday_data['AUTHOR'].value_counts()
print("\nTop 5 authors on Weekdays \n",x18[:6])
print("\nLeast popular 5 authors on Weekdays \n",x18.tail(5))
# Out:
# Top 5 authors on Weekdays
#  None               15208
# Ron Dicker          1060
# Ed Mazza             796
# Lee Moran            787
# Carly Ledbetter      657
# Andy McDonald        574
# Name: AUTHOR, dtype: int64
#
# Least popular 5 authors on Weekdays
#  Barry Wilner & Tom Canavan, AP                                                                   1
# Cooper Koch, Contributor\r\nHusband to Todd, Dad to Claire & Mason, Founder of Cooper Smit...    1
# Peyton Price and Stephanie Sprenger, Contributors                                                1
# Carine Fabius, ContributorAuthor, art dealer, museum curator and temporary body art pioneer      1
# Aaron Anson, Contributor\r\nInspirational self-help speaker and author, 'Mind Your Own Lif...    1
# Name: AUTHOR, dtype: int64

# %%
x18=weekend_data['AUTHOR'].value_counts()
print("\nTop 5 authors on Weekends \n",x18[:6])
print("\nLeast popular 5 authors on Weekends \n",x18.tail(5))
# Out:
# Top 5 authors on Weekends
#  None                16223
# Lee Moran            1339
# Reuters, Reuters      848
# Mary Papenfuss        650
# Ron Dicker            496
# Bill Bradley          480
# Name: AUTHOR, dtype: int64
#
# Least popular 5 authors on Weekends
#  Martin J. Bernstein, Contributor\r\nWriter, hiker and nature enthusiast                          1
# Tom Schraeder, Contributor\r\nMusician/Blogger                                                   1
# Carla Herreria and Ryan J. Reilly                                                                1
# Taina Bien-Aime, ContributorExecutive Director, Coalition Against Trafficking in Women (CATW)    1
# George Clooney, Contributor                                                                      1
# Name: AUTHOR, dtype: int64

# %%
x18=weekday_data['CATEGORY'].value_counts()
print("\nTop 5 categories on Weekdays \n",x18[:6])
print("\nLeast 5 categories on Weekdays \n",x18.tail(5))
# Out:
# Top 5 categories on Weekdays
#  POLITICS          15019
# WELLNESS           9413
# ENTERTAINMENT      6405
# STYLE & BEAUTY     5146
# TRAVEL             5071
# PARENTING          4792
# Name: CATEGORY, dtype: int64
#
# Least 5 categories on Weekdays
#  COLLEGE           553
# FIFTY             512
# EDUCATION         469
# ENVIRONMENT        74
# CULTURE & ARTS     42
# Name: CATEGORY, dtype: int64

# %%
x18=weekend_data['CATEGORY'].value_counts()
print("\nTop 5 categories on Weekends \n",x18[:6])
print("\nLeast 5 categories on Weekends \n",x18.tail(5))
# Out:
# Top 5 categories on Weekends
#  POLITICS         12533
# ENTERTAINMENT     7562
# WELLNESS          5303
# QUEER VOICES      3319
# BUSINESS          3201
# TRAVEL            3098
# Name: CATEGORY, dtype: int64
#
# Least 5 categories on Weekends
#  COLLEGE           410
# EDUCATION         403
# LATINO VOICES     363
# MONEY             362
# ARTS & CULTURE    336
# Name: CATEGORY, dtype: int64

# %%
#AUTHOR PLOT LEE  MORGAN
fig, ax = plt.subplots(1, 1, figsize=(10,10))
df.plot.pie( autopct = '%1.1f%%')

# %%
import pandas as pd
from sklearn import model_selection, preprocessing, linear_model, metrics, svm
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import decomposition, ensemble
#from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
x=data_slicer('26-05-2016','29-06-2018')
trainDF = pd.DataFrame()
trainDF['label']=x['CATEGORY']
trainDF['text']=x['HEADLINE']

# split the dataset into training and validation datasets 
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(trainDF['text'], trainDF['label'])

# create a count vectorizer object 
'''count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')

# transform the training and validation data using count vectorizer object
xtrain_count =  count_vect.fit_transform(train_x.values.astype('U'))
xvalid_count =  count_vect.fit_transform(valid_x.values.astype('U'))'''

# create a count vectorizer object 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
count_vect.fit(trainDF['text'])

# transform the training and validation data using count vectorizer object
xtrain_count =  count_vect.transform(train_x)
xvalid_count =  count_vect.transform(valid_x)

def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)
    
    if is_neural_net:
        predictions = predictions.argmax(axis=-1)
    
    return metrics.accuracy_score(predictions, valid_y)

accuracy = train_model(ensemble.RandomForestClassifier(), xtrain_count, train_y, xvalid_count)
print("RF, Count Vectors: ", accuracy)
# Out:
# RF, Count Vectors:  0.5156044564390008

# %%
from sklearn.svm import LinearSVC

model = LinearSVC()
model.fit(xtrain_count,train_y)
Y_predict = model.predict(xvalid_count)
accuracy = accuracy_score(valid_y,Y_predict)*100
print(format(accuracy, '.2f'))
# Out:
# 58.63

# %%
logistic_Regression = LogisticRegression()
logistic_Regression.fit(xtrain_count,train_y)
Y_predict = logistic_Regression.predict(xvalid_count)
accuracy = accuracy_score(valid_y,Y_predict)*100
print(format(accuracy, '.2f'))
# Out:
# 62.98
